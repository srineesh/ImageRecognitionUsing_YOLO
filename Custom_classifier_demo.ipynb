# %%
import cv2
from darkflow.net.build import TFNet
import numpy as np
import time

# %%
options= {
    'model' : 'cfg/tiny-yolo-voc-1c.cfg',
    'load': 125,
    'threshold' : 0.1
}
tfnet = TFNet(options)
# Out:
# Parsing cfg/tiny-yolo-voc-1c.cfg
# Loading None ...
# Finished in 0.0002009868621826172s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 30)
# -------+--------+----------------------------------+---------------
# Running entirely on CPU
# Loading from ./ckpt/tiny-yolo-voc-1c-125
# INFO:tensorflow:Restoring parameters from ./ckpt/tiny-yolo-voc-1c-125
# Finished in 4.723214864730835s

# %%
colors = [tuple(255 * np.random.rand(3)) for _ in range(10)]

# %%
capture = cv2.VideoCapture(0)
capture.set(cv2.CAP_PROP_FRAME_WIDTH,640)
capture.set(cv2.CAP_PROP_FRAME_HEIGHT,480)
# Out:
# True

# %%
while(capture.isOpened()):
    stime = time.time()
    ret,frame = capture.read()
    results = tfnet.return_predict(frame)
    if ret:
        for color,result in zip(colors,results):
            t1 = (result['topleft']['x'],result['topleft']['y'])
            br = (result['bottomright']['x'],result['bottomright']['y'])
            label = result['label']
            frame = cv2.rectangle(frame,t1,br,color,7)
            frame = cv2.putText(frame,label,t1,cv2.FONT_HERSHEY_COMPLEX,1,(0,0,0),2)
        cv2.imshow('frame',frame)
        print('FPS{:.1f}'.format(1/(time.time() - stime)))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        capture.release()
        cv2.destroyAllWindows()
        break
# Out:
# FPS1.5
# FPS3.7
# FPS4.2
# FPS4.2
# FPS3.9
# FPS4.2
# FPS3.4
# FPS3.7
# FPS3.9
# FPS3.5
# FPS4.2
# FPS3.8
# FPS4.1
# FPS4.2
# FPS4.3
# FPS3.9
# FPS4.5
# FPS4.1
# FPS4.5
# FPS4.5
# FPS4.4
# FPS4.3
# FPS4.3
# FPS4.4
# FPS4.4
# FPS4.5
# FPS4.2
# FPS4.6
# FPS4.3
# FPS4.3
# FPS4.3
# FPS4.6
# FPS4.2
# FPS4.4
# FPS4.4
# FPS4.3
# FPS4.5
# FPS4.5
# FPS4.0
# FPS3.8
# FPS4.2
# FPS3.8
# FPS3.5
# FPS4.4
# FPS4.3
# FPS4.4
# FPS4.5
# FPS4.5
# FPS4.4
# FPS4.2
# FPS4.6
# FPS4.2
# FPS4.4
# FPS4.2
# FPS4.6
# FPS4.4
# FPS4.5
# FPS4.2
# FPS4.5
# FPS4.5
# FPS4.4
# FPS4.3
# FPS4.6
# FPS4.2
# FPS4.4
# FPS4.5
# FPS4.8
# FPS4.6
# FPS4.3
# FPS4.5
# FPS4.2
# FPS4.4
# FPS4.4
# FPS4.3
# FPS4.5
# FPS4.4
# FPS4.6
# FPS4.7
# FPS4.4
# FPS4.4
# FPS4.5
# FPS4.4
# FPS4.4
# FPS4.2
# FPS4.2
# FPS4.5
# FPS4.1
# FPS4.4
# FPS4.2
# FPS4.5
# FPS4.4
# FPS4.7
# FPS3.7
# FPS4.4
# FPS4.1
# FPS4.6
# FPS4.2
# FPS4.8
# FPS4.5
# FPS4.5
# FPS4.3
# FPS4.1
# FPS4.3
